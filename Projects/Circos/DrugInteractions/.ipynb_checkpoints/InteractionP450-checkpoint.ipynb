# %% [markdown]
# # Import circos Module

# %%
from circos import CircosPlot
import xlrd
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Load the File of Medication Data Table from FDA Website

# %%
#Load the File
filename='.\\MedicationInteraction.xlsx'
book=xlrd.open_workbook(filename)
print('File loaded!')
# Out:
# File loaded!

# %% [markdown]
# # Extract Data

# %%
nrows = book.sheet_by_name('Sheet1').nrows

# %%
header = book.sheet_by_name('Sheet1').row_values(0)
data = [book.sheet_by_name('Sheet1').row_values(i) for i in range(1, nrows)]
df = pd.DataFrame(data, columns = header)

# %%
df[df == ''] = np.nan

# %%
df
# Out:
#              CYP1A2            CYP2B6        CYP2C8         CYP2C9  \
# 0         clozapine       artemisinin    paclitaxel     diclofenac
# 1   cyclobenzaprine         bupropion     torsemide      ibuprofen
# 2        duloxetine  cyclophosphamide   amodiaquine       naproxen
# 3       fluvoxamine         efavirenz  cerivastatin      piroxicam
# 4       haloperidol        ifosfamide   repaglinide    tolbutamide
# 5        imipramine          ketamine           NaN      glipizide
# 6        mexiletine        meperidine           NaN      glyburide
# 7        nabumetone         methadone           NaN       losartan
# 8          naproxen        nevirapine           NaN     irbesartan
# 9        olanzapine          propofol           NaN      celecoxib
# 10     zolmitriptan        selegiline           NaN    zafirlukast
# 11         riluzole               NaN           NaN    fluvastatin
# 12          tacrine               NaN           NaN      phenytoin
# 13     theophylline               NaN           NaN  rosiglitazone
# 14       tizanidine               NaN           NaN      torsemide
# 15      triamterene               NaN           NaN  valproic acid
# 16         zileuton               NaN           NaN       warfarin
# 17              NaN               NaN           NaN            NaN
# 18              NaN               NaN           NaN            NaN
# 19              NaN               NaN           NaN            NaN
# 20              NaN               NaN           NaN            NaN
# 21              NaN               NaN           NaN            NaN
# 22              NaN               NaN           NaN            NaN
# 23              NaN               NaN           NaN            NaN
# 24              NaN               NaN           NaN            NaN
# 25              NaN               NaN           NaN            NaN
# 26              NaN               NaN           NaN            NaN
# 27              NaN               NaN           NaN            NaN
# 28              NaN               NaN           NaN            NaN
# 29              NaN               NaN           NaN            NaN
# 30              NaN               NaN           NaN            NaN
# 31              NaN               NaN           NaN            NaN
# 32              NaN               NaN           NaN            NaN
# 33              NaN               NaN           NaN            NaN
# 34              NaN               NaN           NaN            NaN
# 35              NaN               NaN           NaN            NaN
# 36              NaN               NaN           NaN            NaN
# 37              NaN               NaN           NaN            NaN
# 38              NaN               NaN           NaN            NaN
# 39              NaN               NaN           NaN            NaN
# 40              NaN               NaN           NaN            NaN
# 41              NaN               NaN           NaN            NaN
# 42              NaN               NaN           NaN            NaN
# 43              NaN               NaN           NaN            NaN
#
#              CYP2C19            CYP2D6          CYP2E1            CYP3A4
# 0       esomeprazole        carvedilol       enflurane    clarithromycin
# 1       lansoprazole      S-metoprolol       halothane      erythromycin
# 2         omeprazole       propafenone      isoflurane     telithromycin
# 3       pantoprazole           timolol  methoxyflurane         quinidine
# 4           diazepam     amitriptyline     sevoflurane        alprazolam
# 5          phenytoin      clomipramine   acetaminophen          diazepam
# 6     phenobarbitone       desipramine         benzene         midazolam
# 7      amitriptyline        duloxetine   chlorzoxazone         triazolam
# 8       carisoprodol        fluoxetine         ethanol      cyclosporine
# 9         citalopram        imipramine    theophylline        tacrolimus
# 10      clomipramine        paroxetine         aniline         sirolimus
# 11       clopidogrel       haloperidol             NaN         indinavir
# 12  cyclophosphamide       venlafaxine             NaN         ritonavir
# 13        imipramine       risperidone             NaN        saquinavir
# 14         labetalol      thioridazine             NaN        nevirapine
# 15         proguanil      aripiprazole             NaN         cisapride
# 16      voriconazole       atomoxetine             NaN        astemizole
# 17               NaN           codeine             NaN  chlorpheniramine
# 18               NaN  dextromethorphan             NaN        amlodipine
# 19               NaN          tramadol             NaN         diltiazem
# 20               NaN          doxepine             NaN        felodipine
# 21               NaN        flecainide             NaN        nifedipine
# 22               NaN        mexiletine             NaN       nisoldipine
# 23               NaN       ondansetron             NaN      nitrendipine
# 24               NaN         oxycodone             NaN         verapamil
# 25               NaN       risperidone             NaN      atorvastatin
# 26               NaN         tamoxifen             NaN        lovastatin
# 27               NaN               NaN             NaN       simvastatin
# 28               NaN               NaN             NaN        sildenafil
# 29               NaN               NaN             NaN         tadalafil
# 30               NaN               NaN             NaN        vardenafil
# 31               NaN               NaN             NaN        alfentanyl
# 32               NaN               NaN             NaN      aripiprazole
# 33               NaN               NaN             NaN        boceprevir
# 34               NaN               NaN             NaN         buspirone
# 35               NaN               NaN             NaN       vincristine
# 36               NaN               NaN             NaN     carbamazepine
# 37               NaN               NaN             NaN           gleevec
# 38               NaN               NaN             NaN       haloperidol
# 39               NaN               NaN             NaN          pimozide
# 40               NaN               NaN             NaN           quinine
# 41               NaN               NaN             NaN         tamoxifen
# 42               NaN               NaN             NaN        telaprevir
# 43               NaN               NaN             NaN         trazodone

# %% [markdown]
# # Data Munging

# %%
df_dict = {}
for i in range(len(df.columns)):
    df_dict[df.icol(i).name] = list(df.icol(i).dropna())

# %% [markdown]
# ## Nodes

# %%
nodes = []
for key in df_dict.keys():
    nodes.extend(df_dict[key])
    #nodes.extend(['0']*3)

# %%
nodes = list(nodes)

# %%
headers = list(df.columns)

# %%
enzymes = ['0'] * 5
for header in headers:
    enzymes.append(header)
    enzymes.extend(['0']*5)

# %%
nodes.extend(enzymes)

# %% [markdown]
# ## Edges

# %%
edges_origin = []
for key in df_dict.keys():
    for value in df_dict[key]:
        edges_origin.append((key, value))

# %%
#nodeprops = dict(facecolor='green', alpha=1)
#edgeprops = dict(edgecolor='red', alpha=1, ls='--')

# %% [markdown]
# # Plotting the All-in-one Circos

# %%
c = CircosPlot(nodes, edges_origin, radius = 10, 
              nodecolor="blue",
              edgecolor="red",
              )
c.draw()

# %% [markdown]
# # Build Drug Circos Plotting Corresponding Enzymes

# %% [markdown]
# ## CYP1A2

# %%
edges = []
for value in df_dict['CYP1A2']:
    edges.append(('CYP1A2', value))

# %%
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="green",
              edgecolor="green",
              )
c.draw()

# %% [markdown]
# ## CYP2B6

# %%
edges = []
for value in df_dict['CYP2B6']:
    edges.append(('CYP2B6', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="orange",
              edgecolor="orange",
              )
c.draw()

# %% [markdown]
# ## CYP2C8

# %%
edges = []
for value in df_dict['CYP2C8']:
    edges.append(('CYP2C8', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="purple",
              edgecolor="purple",
              )
c.draw()

# %% [markdown]
# ## CYP2C9

# %%
edges = []
for value in df_dict['CYP2C9']:
    edges.append(('CYP2C9', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="cyan",
              edgecolor="cyan",
              )
c.draw()

# %% [markdown]
# ## CYP2C19

# %%
edges = []
for value in df_dict['CYP2C19']:
    edges.append(('CYP2C19', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="red",
              edgecolor="red",
              )
c.draw()

# %% [markdown]
# ## CYP2D6

# %%
edges = []
for value in df_dict['CYP2D6']:
    edges.append(('CYP2D6', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="yellow",
              edgecolor="yellow",
              )
c.draw()

# %% [markdown]
# ## CYP2E1

# %%
edges = []
for value in df_dict['CYP2E1']:
    edges.append(('CYP2E1', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="magenta",
              edgecolor="magenta",
              )
c.draw()

# %% [markdown]
# ## CYP3A4

# %%
edges = []
for value in df_dict['CYP3A4']:
    edges.append(('CYP3A4', value))
    
c = CircosPlot(nodes, edges, radius = 10, 
              nodecolor="blue",
              edgecolor="blue",
              )
c.draw()

# %% [markdown]
# # Pick up 14 Specific Medications

# %% [markdown]
# They are propafenone（心律平）, acetaminophen（对乙酰氨基酚）, paclitaxel（紫杉醇）, ibuprofen（布洛芬）, losartan（洛沙坦）, omeprazole（奥美拉唑）, carvediolo（卡维地洛）, codeine（可待因）, theophylline（茶碱）, quinidine（奎尼丁）, verapamil（异搏定）, lovastatin（洛伐他汀）, nitrendipine（尼群地平）.

# %%
medications = ['propafenone', 'acetaminophen', 'paclitaxel', 'ibuprofen', 'losartan', 
               'omeprazole', 'carvedilol', 'codeine', 'theophylline', 'quinidine', 'verapamil', 
               'lovastatin', 'nitrendipine']
edges_candidate = set()

for medication in medications:
    for edge in edges_origin:
        if medication == edge[1]:
            edges_candidate.add(edge)
edges_candidate = list(edges_candidate)

# %%
c = CircosPlot(nodes, edges_candidate, radius = 10, 
              nodecolor="black",
              edgecolor="black",
              )
c.draw()

# %% [markdown]
# ## Save to a File

# %% [markdown]
# ### c.fig is matplotlib object, and must be assigned to a new variable

# %%
# Key step!
figure = c.fig

# %%
type(figure)
# Out:
# matplotlib.figure.Figure

# %%
figure

# %% [markdown]
# ### Then this object can be saved

# %%
figure.savefig('medicationInterested.png', dpi=600)
