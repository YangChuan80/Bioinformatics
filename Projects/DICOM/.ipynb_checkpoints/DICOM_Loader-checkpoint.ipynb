# %%
import SimpleITK as sitk
from PIL import Image

# %%
ds = sitk.ReadImage('0000000D')

# %%
img_matrix = sitk.GetArrayFromImage(ds)

# %%
type(img_matrix[3])
# Out:
# numpy.ndarray

# %%
img = Image.fromarray(img_matrix[20])

# %%
n = len(img_matrix)

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x70C9C18>
