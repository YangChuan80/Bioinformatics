# %% [markdown]
# ### Module Importation

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math
import statistics
# %matplotlib inline

# %% [markdown]
# ### Load the ECG Array File

# %%
filename = 'V6'

# %%
leadName_load = np.load('ECG_Output/' + filename + '_array.npy')

# %%
leadName_load.shape
# Out:
# (2, 1867)

# %%
leadName_load[0]
# Out:
# array([0.00000000e+00, 2.53807107e-03, 5.07614213e-03, ...,
#        4.73096447e+00, 4.73350254e+00, 4.73604061e+00])

# %%
leadName_load[1]
# Out:
# array([-0.52030457, -0.51395939, -0.48857868, ...,  0.13959391,
#         0.15228426,  0.15862944])

# %% [markdown]
# ### Output the ECG data globally

# %%
fig = plt.figure()
s = fig.add_subplot(111)

s.plot(leadName_load[0], leadName_load[1], linewidth=1.2, color='black')

s.set_xticks(np.arange(0, leadName_load[0][-1]+ 0.2, 0.2))
s.set_yticks(np.arange(-4, 4, 0.5))
plt.grid(True, color='r', linestyle='--', linewidth=0.5)

# %%
fig.savefig('ECG_Output/ECG_reload_' + filename + '_output.png', dpi=400)
